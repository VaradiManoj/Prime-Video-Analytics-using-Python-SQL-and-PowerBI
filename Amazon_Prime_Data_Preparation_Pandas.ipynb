# %%
# Importing pandas and numpy, setting display options

import pandas as pd
import numpy as np
pd.set_option("display.max_columns",None)
pd.set_option("display.width",None)
pd.set_option("display.max_colwidth",None)

# %%
# Importing/loading all 4 CSV files into pandas dataframes

movies = pd.read_csv("I:\\Prime_Video_Project\\movies.csv")
users = pd.read_csv("I:\\Prime_Video_Project\\users.csv")
watch_history = pd.read_csv("I:\\Prime_Video_Project\\watch_history.csv")
subscription_plans = pd.read_csv("I:\\Prime_Video_Project\\subscription_plans.csv")

# %%
# Previewing first 5 rows of movies
movies.head()
# Out:
#   movie_id         title language    genre  release_year decade  \
# 0   M00001    John Rambo    Tamil   Action          2008  2000s
# 1   M00002  American Pie  English   Action          1999  1990s
# 2   M00003     Bombshell  English    Drama          2019  2010s
# 3   M00004    Love Birds    Tamil  Romance          1996  1990s
# 4   M00005         Hippi   Telugu  Romance          2019  2010s
#
#    running_time_minutes  imdb_rating rating_category maturity_rating  \
# 0                    86          7.0            Good             18+
# 1                    95          7.0            Good             18+
# 2                   108          6.8            Good             18+
# 3                   160          5.1         Average             All
# 4                   140          5.0         Average             18+
#
# ...

# %%
# Previewing first 5 rows of movies
users.head()
# Out:
#   user_id          name  age  gender       city        state plan_id  \
# 0  U00001    Anvi Konda   53  Female  Hyderabad    Telangana      P1
# 1  U00002    Gagan Sami   43   Other  Hyderabad    Telangana      P2
# 2  U00003    Tejas Kaul   29    Male     Mumbai  Maharashtra      P1
# 3  U00004  Rushil Saini   57   Other       Pune  Maharashtra      P2
# 4  U00005   Abeer Dutta   22    Male   Guwahati        Assam      P1
#
#   signup_date preferred_language  is_active
# 0  2025-02-04              Hindi       True
# 1  2023-06-07              Hindi       True
# 2  2022-08-31             Telugu       True
# 3  2024-07-23             Telugu       True
# 4  2023-06-03            Bengali       True

# %%
# Previewing first 5 rows of movies
watch_history.head()
# Out:
#   interaction_id user_id movie_id  watch_date  watch_duration_minutes  \
# 0        I000001  U00599   M04770  2024-12-23                      22
# 1        I000002  U01957   M00701  2025-06-25                     118
# 2        I000003  U01694   M00532  2025-10-02                     157
# 3        I000004  U01076   M06548  2025-11-12                     134
# 4        I000005  U01617   M05283  2023-05-15                     153
#
#    completed  user_rating device_type
# 0      False            5      Laptop
# 1       True            3      Mobile
# 2       True            4      Mobile
# 3       True            5      Tablet
# 4       True            5    Smart TV

# %%
# Previewing first 5 rows of movies
subscription_plans.head()
# Out:
#   plan_id                   plan_name  price_inr billing_cycle  max_screens  \
# 0      P1               Prime Monthly        299       Monthly            2
# 1      P2                Prime Annual       1499        Yearly            2
# 2      P3                  Prime Lite        799        Yearly            1
# 3      P4  Prime Video Mobile Edition        599        Yearly            1
#
#   video_quality  includes_ads
# 0            HD         False
# 1            HD         False
# 2            SD          True
# 3            SD          True

# %%
#Checking shape (rows, columns) of movies
movies.shape
# Out:
# (8127, 14)

# %%
#Checking shape (rows, columns) of users
users.shape
# Out:
# (3000, 10)

# %%
#Checking shape (rows, columns) of watch_history
watch_history.shape
# Out:
# (60000, 8)

# %%
#Checking shape (rows, columns) of subscription_plans
subscription_plans.shape
# Out:
# (4, 7)

# %%
#Checking structure and data types of movies
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8127 entries, 0 to 8126
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_id              8127 non-null   str
#  1   title                 8127 non-null   str
#  2   language              8127 non-null   str
#  3   genre                 8127 non-null   str
#  4   release_year          8127 non-null   int64
#  5   decade                8127 non-null   str
#  6   running_time_minutes  8127 non-null   int64
#  7   imdb_rating           8127 non-null   float64
#  8   rating_category       8127 non-null   str
#  9   maturity_rating       8127 non-null   str
#  10  plot                  8127 non-null   str
#  11  plot_word_count       8127 non-null   int64
#  12  is_rating_imputed     8127 non-null   bool
#  13  is_year_imputed       8127 non-null   bool
# dtypes: bool(2), float64(1), int64(3), str(8)
# memory usage: 777.9 KB

# %%
#Checking structure and data types of uers
users.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             3000 non-null   str
#  1   name                3000 non-null   str
#  2   age                 3000 non-null   int64
#  3   gender              3000 non-null   str
#  4   city                3000 non-null   str
#  5   state               3000 non-null   str
#  6   plan_id             3000 non-null   str
#  7   signup_date         3000 non-null   str
#  8   preferred_language  3000 non-null   str
#  9   is_active           3000 non-null   bool
# dtypes: bool(1), int64(1), str(8)
# memory usage: 214.0 KB

# %%
#Checking structure and data types of watch_history
watch_history.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   interaction_id          60000 non-null  str
#  1   user_id                 60000 non-null  str
#  2   movie_id                60000 non-null  str
#  3   watch_date              60000 non-null  str
#  4   watch_duration_minutes  60000 non-null  int64
#  5   completed               60000 non-null  bool
#  6   user_rating             60000 non-null  int64
#  7   device_type             60000 non-null  str
# dtypes: bool(1), int64(2), str(5)
# memory usage: 3.3 MB

# %%
#Checking structure and data types of subscription_plans
subscription_plans.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   plan_id        4 non-null      str
#  1   plan_name      4 non-null      str
#  2   price_inr      4 non-null      int64
#  3   billing_cycle  4 non-null      str
#  4   max_screens    4 non-null      int64
#  5   video_quality  4 non-null      str
#  6   includes_ads   4 non-null      bool
# dtypes: bool(1), int64(2), str(4)
# memory usage: 328.0 bytes

# %%
# Converting Date Columns to Datetime Format
users["signup_date"]=pd.to_datetime(users["signup_date"])

# %%
# Confirming signup_date dtype changed to datetime
users.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             3000 non-null   str
#  1   name                3000 non-null   str
#  2   age                 3000 non-null   int64
#  3   gender              3000 non-null   str
#  4   city                3000 non-null   str
#  5   state               3000 non-null   str
#  6   plan_id             3000 non-null   str
#  7   signup_date         3000 non-null   datetime64[us]
#  8   preferred_language  3000 non-null   str
#  9   is_active           3000 non-null   bool
# dtypes: bool(1), datetime64[us](1), int64(1), str(7)
# memory usage: 214.0 KB

# %%
# Converting watch_date column to datetime format
watch_history["watch_date"] = pd.to_datetime(watch_history["watch_date"])

# %%
# Confirming watch_date dtype changed to datetime
watch_history.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   interaction_id          60000 non-null  str
#  1   user_id                 60000 non-null  str
#  2   movie_id                60000 non-null  str
#  3   watch_date              60000 non-null  datetime64[us]
#  4   watch_duration_minutes  60000 non-null  int64
#  5   completed               60000 non-null  bool
#  6   user_rating             60000 non-null  int64
#  7   device_type             60000 non-null  str
# dtypes: bool(1), datetime64[us](1), int64(2), str(4)
# memory usage: 3.3 MB

# %%
#Descriptive statistics for movies
movies.describe(include="all")
# Out:
#        movie_id       title language  genre  release_year decade  \
# count      8127        8127     8127   8127   8127.000000   8127
# unique     8127        7261       10      9           NaN      8
# top      M00001  Flight 192    Hindi  Drama           NaN  2010s
# freq          1           8     1982   3657           NaN   4088
# mean        NaN         NaN      NaN    NaN   2007.190845    NaN
# std         NaN         NaN      NaN    NaN     13.221410    NaN
# min         NaN         NaN      NaN    NaN   1952.000000    NaN
# 25%         NaN         NaN      NaN    NaN   2000.000000    NaN
# 50%         NaN         NaN      NaN    NaN   2012.000000    NaN
# 75%         NaN         NaN      NaN    NaN   2017.000000    NaN
# max         NaN         NaN      NaN    NaN   2021.000000    NaN
#
#         running_time_minutes  imdb_rating rating_category maturity_rating  \
# count            8127.000000  8127.000000            8127            8127
# ...

# %%
#Descriptive statistics for users
users.describe(include="all")
# Out:
#        user_id           name         age gender         city        state  \
# count     3000           3000  3000.00000   3000         3000         3000
# unique    3000           2975         NaN      3           20           15
# top     U00001  Ikbal Kothari         NaN   Male  Bhubaneswar  Maharashtra
# freq         1              2         NaN   1039          168          426
# mean       NaN            NaN    39.55300    NaN          NaN          NaN
# min        NaN            NaN    15.00000    NaN          NaN          NaN
# 25%        NaN            NaN    27.00000    NaN          NaN          NaN
# 50%        NaN            NaN    40.00000    NaN          NaN          NaN
# 75%        NaN            NaN    51.00000    NaN          NaN          NaN
# max        NaN            NaN    64.00000    NaN          NaN          NaN
# std        NaN            NaN    14.33426    NaN          NaN          NaN
#
# ...

# %%
#Descriptive statistics for watch_history
watch_history.describe(include="all")
# Out:
#        interaction_id user_id movie_id                  watch_date  \
# count           60000   60000    60000                       60000
# unique          60000    3000     8117                         NaN
# top           I000001  U00725   M06870                         NaN
# freq                1      37       20                         NaN
# mean              NaN     NaN      NaN  2025-07-14 16:53:08.160000
# min               NaN     NaN      NaN         2022-07-25 00:00:00
# 25%               NaN     NaN      NaN         2025-01-01 00:00:00
# 50%               NaN     NaN      NaN         2025-10-15 00:00:00
# 75%               NaN     NaN      NaN         2026-04-10 00:00:00
# max               NaN     NaN      NaN         2026-07-15 00:00:00
# std               NaN     NaN      NaN                         NaN
#
#         watch_duration_minutes completed   user_rating device_type
# count             60000.000000     60000  60000.000000       60000
# ...

# %%
#Descriptive statistics for subscription_plans
subscription_plans.describe(include="all")
# Out:
#        plan_id      plan_name    price_inr billing_cycle  max_screens  \
# count        4              4     4.000000             4      4.00000
# unique       4              4          NaN             2          NaN
# top         P1  Prime Monthly          NaN        Yearly          NaN
# freq         1              1          NaN             3          NaN
# mean       NaN            NaN   799.000000           NaN      1.50000
# std        NaN            NaN   509.901951           NaN      0.57735
# min        NaN            NaN   299.000000           NaN      1.00000
# 25%        NaN            NaN   524.000000           NaN      1.00000
# 50%        NaN            NaN   699.000000           NaN      1.50000
# 75%        NaN            NaN   974.000000           NaN      2.00000
# max        NaN            NaN  1499.000000           NaN      2.00000
#
#        video_quality includes_ads
# count              4            4
# unique             2            2
# ...

# %%
#Checking missing values in movies
movies.isnull().sum()
# Out:
# movie_id                0
# title                   0
# language                0
# genre                   0
# release_year            0
# decade                  0
# running_time_minutes    0
# imdb_rating             0
# rating_category         0
# maturity_rating         0
# plot                    0
# plot_word_count         0
# is_rating_imputed       0
# is_year_imputed         0
# dtype: int64

# %%
#Checking missing values in users
users.isnull().sum()
# Out:
# user_id               0
# name                  0
# age                   0
# gender                0
# city                  0
# state                 0
# plan_id               0
# signup_date           0
# preferred_language    0
# is_active             0
# dtype: int64

# %%
#Checking missing values in watch_history
watch_history.isnull().sum()
# Out:
# interaction_id            0
# user_id                   0
# movie_id                  0
# watch_date                0
# watch_duration_minutes    0
# completed                 0
# user_rating               0
# device_type               0
# dtype: int64

# %%
#Checking missing values in subscription_plans
subscription_plans.isnull().sum()
# Out:
# plan_id          0
# plan_name        0
# price_inr        0
# billing_cycle    0
# max_screens      0
# video_quality    0
# includes_ads     0
# dtype: int64

# %%
# Checking duplicate rows in movies
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking duplicate rows in users
users.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking duplicate rows in watch_history
watch_history.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking duplicate rows in subscription_plans
subscription_plans.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check for unrealistic age values
users[(users["age"] < 15) | (users["age"] > 100)]
# Out:
# Empty DataFrame
# Columns: [user_id, name, age, gender, city, state, plan_id, signup_date, preferred_language, is_active]
# Index: []

# %%
# Counting how many unrealistic age values exist
((users["age"] < 15) | (users["age"] > 100)).sum()
# Out:
# np.int64(0)

# %%
# Viewing movies column names for reference
movies.columns
# Out:
# Index(['movie_id', 'title', 'language', 'genre', 'release_year', 'decade',
#        'running_time_minutes', 'imdb_rating', 'rating_category',
#        'maturity_rating', 'plot', 'plot_word_count', 'is_rating_imputed',
#        'is_year_imputed'],
#       dtype='str')

# %%
# Check for invalid IMDb ratings (outside 0-10 range)
movies[(movies["imdb_rating"]<0) |  (movies["imdb_rating"]>10)]
# Out:
# Empty DataFrame
# Columns: [movie_id, title, language, genre, release_year, decade, running_time_minutes, imdb_rating, rating_category, maturity_rating, plot, plot_word_count, is_rating_imputed, is_year_imputed]
# Index: []

# %%
# Counting how many invalid IMDb ratings exist
((movies["imdb_rating"]<0) |  (movies["imdb_rating"]>10)).sum()
# Out:
# np.int64(0)

# %%
# Viewing users column names for reference
users.columns
# Out:
# Index(['user_id', 'name', 'age', 'gender', 'city', 'state', 'plan_id',
#        'signup_date', 'preferred_language', 'is_active'],
#       dtype='str')

# %%
# Viewing watch_history column names for reference
watch_history.columns
# Out:
# Index(['interaction_id', 'user_id', 'movie_id', 'watch_date',
#        'watch_duration_minutes', 'completed', 'user_rating', 'device_type'],
#       dtype='str')

# %%
# Check for invalid user_rating values (outside 0-5 range)
watch_history[(watch_history["user_rating"]<0) | (watch_history["user_rating"]>5)]
# Out:
# Empty DataFrame
# Columns: [interaction_id, user_id, movie_id, watch_date, watch_duration_minutes, completed, user_rating, device_type]
# Index: []

# %%
# Counting how many invalid user_rating values exist
((watch_history["user_rating"]<0) | (watch_history["user_rating"]>1)).sum()
# Out:
# np.int64(0)

# %%
# Referential integrity check: watch_history user_id not present in users
watch_history[~watch_history["user_id"].isin(users["user_id"])]
# Out:
# Empty DataFrame
# Columns: [interaction_id, user_id, movie_id, watch_date, watch_duration_minutes, completed, user_rating, device_type]
# Index: []

# %%
# Counting how many watch_history rows have an unknown user_id
(~watch_history["user_id"].isin(users["user_id"])).sum()
# Out:
# np.int64(0)

# %%
#Referential integrity check: watch_history movie_id not present in movies
watch_history[~watch_history["movie_id"].isin(movies["movie_id"])]
# Out:
# Empty DataFrame
# Columns: [interaction_id, user_id, movie_id, watch_date, watch_duration_minutes, completed, user_rating, device_type]
# Index: []

# %%
# Counting how many watch_history rows have an unknown movie_id
(~watch_history["movie_id"].isin(movies["movie_id"])).sum()
# Out:
# np.int64(0)

# %%
# Referential integrity check: users plan_id not present in subscription_plans
users[~users["plan_id"].isin(subscription_plans["plan_id"])]
# Out:
# Empty DataFrame
# Columns: [user_id, name, age, gender, city, state, plan_id, signup_date, preferred_language, is_active]
# Index: []

# %%
# Counting how many users have an unknown plan_id
(~users["plan_id"].isin(subscription_plans["plan_id"])).sum()
# Out:
# np.int64(0)

# %%
# Saving cleaned movies, users, watch_history, and subscription_plans data back to CSV
movies.to_csv("I:\\Prime_Video_Project\\movies.csv",index=False)
users.to_csv("I:\\Prime_Video_Project\\users.csv",index=False)
watch_history.to_csv("I:\\Prime_Video_Project\\watch_history.csv",index=False)
subscription_plans.to_csv("I:\\Prime_Video_Project\\subscription_plans.csv",index=False)
